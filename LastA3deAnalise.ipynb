# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielCastro8/EntregaFinalA3/blob/main/LastA3deAnalise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Criar dataset

# %% [markdown]
# Gabriel Antonio Lopes de Castro - 1272023100<br>

# %% [markdown]
# ##Configuracoes

# %%
# Python ≥3.5 é obrigatório
import sys
assert sys.version_info >= (3, 5)
# Scikit-Learn ≥0.20 é obrigatório
import sklearn
assert sklearn.__version__ >= "0.20"
# Importações comuns
import numpy as np
import os
# Commented out IPython magic to ensure Python compatibility.

# %%
# Para traçar figuras bonitas
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import pandas as pd

# %% [markdown]
# ##Primeiro dataset

# %% [markdown]
# ##Dados das Olimpiadas de 2016

# %% [markdown]
# Dados pego no kaggle<br>
# link:

# %% [markdown]
# https://www.kaggle.com/datasets/rio2016/olympic-games?select=countries.csv

# %% [markdown]
# Criando o dataframe com os arquivos

# %%
data1 = pd.read_csv("athletes.csv")

# %% [markdown]
# exibindo as 5 primeiras linhas para analisar

# %%
data1.head() # Comando para mostrar as primeiras 5 linhas do dataframe
# Out:
#           id            name nationality     sex       dob  height  weight  \
# 0  736041664  A Jesus Garcia         ESP    male  10/17/69    1.72    64.0
# 1  532037425      A Lam Shin         KOR  female   9/23/86    1.68    56.0
# 2  435962603     Aaron Brown         CAN    male   5/27/92    1.98    79.0
# 3  521041435      Aaron Cook         MDA    male    1/2/91    1.83    80.0
# 4   33922579      Aaron Gate         NZL    male  11/26/90    1.81    71.0
#
#        sport  gold  silver  bronze
# 0  athletics     0       0       0
# 1    fencing     0       0       0
# 2  athletics     0       0       1
# 3  taekwondo     0       0       0
# 4    cycling     0       0       0

# %% [markdown]
# exibindo as 5 ultimas linhas

# %%
data1.tail()
# Out:
#               id                name nationality     sex       dob  height  \
# 11533  265605954  Zurian Hechavarria         CUB  female   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE  female  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    male   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    male    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    male    1/6/92    1.85
#
#        weight          sport  gold  silver  bronze
# 11533    58.0      athletics     0       0       0
# 11534    63.0      athletics     0       0       0
# 11535   100.0      wrestling     0       0       0
# 11536    56.0  weightlifting     0       0       0
# 11537    70.0      athletics     0       0       0

# %% [markdown]
# Vendo informacoes sobre o dataframe para ver dados ausentes

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11538 entries, 0 to 11537
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11538 non-null  int64
#  1   name         11538 non-null  object
#  2   nationality  11538 non-null  object
#  3   sex          11538 non-null  object
#  4   dob          11537 non-null  object
#  5   height       11208 non-null  float64
#  6   weight       10879 non-null  float64
#  7   sport        11538 non-null  object
#  8   gold         11538 non-null  int64
#  9   silver       11538 non-null  int64
#  10  bronze       11538 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 991.7+ KB

# %% [markdown]
# Foi analisado que dob possui 1 valor ausente, height possui 330 valores ausentes, weight possui 659 valores ausentes que precisam ser tratados

# %% [markdown]
# Vendo um describe para obter informacoes sobre os valores numericos

# %%
data1.describe()
# Out:
#                  id        height        weight          gold        silver  \
# count  1.153800e+04  11208.000000  10879.000000  11538.000000  11538.000000
# mean   4.999885e+08      1.766282     72.068205      0.057722      0.056769
# std    2.908648e+08      0.112719     16.177334      0.255910      0.239147
# min    1.834700e+04      1.210000     31.000000      0.000000      0.000000
# 25%    2.450997e+08      1.690000     60.000000      0.000000      0.000000
# 50%    5.002011e+08      1.760000     70.000000      0.000000      0.000000
# 75%    7.539874e+08      1.840000     81.000000      0.000000      0.000000
# max    9.999878e+08      2.210000    170.000000      5.000000      2.000000
#
#              bronze
# count  11538.000000
# mean       0.061016
# std        0.243320
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000

# %% [markdown]
# Vendo se existem dados duplicados

# %%
data1[data1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, nationality, sex, dob, height, weight, sport, gold, silver, bronze]
# Index: []

# %% [markdown]
# Nao existem linhas duplicadas

# %% [markdown]
# ##Tratamento dos dados ausentes

# %% [markdown]
# Vendo quais sao os valores ausentes de dob

# %%
data1[data1['dob'].isna()]
# Out:
#              id           name nationality   sex  dob  height  weight  \
# 8546  663676373  Pavel Sozykin         RUS  male  NaN     NaN     NaN
#
#         sport  gold  silver  bronze
# 8546  sailing     0       0       0

# %% [markdown]
# Essa linha vai ser eliminada pela ausencia de varios dados

# %%
data1_tratada=data1.dropna(subset=['dob'])

# %% [markdown]
# Vendo quais sao os valores ausentes de height

# %%
data1[data1['height'].isna()]
# Out:
#               id                  name nationality     sex       dob  height  \
# 12     258556239            Abbas Qali         IOA    male  10/11/92     NaN
# 47     469953606    Abdoullah Bamoussa         ITA    male    6/8/86     NaN
# 50     325809293            Abdul Omar         GHA    male   10/3/93     NaN
# 52     262868423    Abdulaziz Alshatti         IOA    male  10/30/90     NaN
# 56     897549624     Abdullah Hel Baki         BAN    male    8/1/89     NaN
# ...          ...                   ...         ...     ...       ...     ...
# 11031  404382792          Winston Hill         FIJ    male   9/17/93     NaN
# 11208  550672127  Yemane Haileselassie         ERI    male   2/21/98     NaN
# 11220    5964702       Yesenia Miranda         ESA  female   3/26/94     NaN
# 11238  390260480        Yigal Kopinsky         SUR    male  10/16/85     NaN
# 11370   86099624         Yulia Efimova         RUS  female    4/3/92     NaN
#
# ...

# %% [markdown]
# Devido a varios valores ausentes, esses dados vao ser eliminados. Essas linhas possuem muitos valores ausentes, em mais de uma coluna, e em sua maioria sao de atletas que nao ganharam

# %%
data1_tratada=data1_tratada.dropna(subset=['height'])

# %% [markdown]
# Vendo quais sao os valores ausentes de weight

# %%
data1[data1['weight'].isna()]
# Out:
#               id                                 name nationality     sex  \
# 12     258556239                           Abbas Qali         IOA    male
# 28     349871091                 Abdelhafid Benchabla         ALG    male
# 30      23564778                     Abdelkader Chadi         ALG    male
# 37     934545704  Abdelrahman Salah Orabi Abdelgawwad         EGY    male
# 47     469953606                   Abdoullah Bamoussa         ITA    male
# ...          ...                                  ...         ...     ...
# 11465  980866226                  Zhaina Shekerbekova         KAZ  female
# 11468  405483135                 Zhanibek Alimkhanuly         KAZ    male
# 11513  352983859                        Zohir Kedache         ALG    male
# 11514  424586991                    Zohra Ez Zahraoui         MAR  female
# 11517  495365659                   Zoltan Adam Harcsa         HUN    male
#
#             dob  height  weight      sport  gold  silver  bronze
# ...

# %% [markdown]
# Eliminando esses valores ausentes

# %%
data1_tratada=data1_tratada.dropna(subset=['weight'])

# %%
data1_tratada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10858 entries, 0 to 11537
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10858 non-null  int64
#  1   name         10858 non-null  object
#  2   nationality  10858 non-null  object
#  3   sex          10858 non-null  object
#  4   dob          10858 non-null  object
#  5   height       10858 non-null  float64
#  6   weight       10858 non-null  float64
#  7   sport        10858 non-null  object
#  8   gold         10858 non-null  int64
#  9   silver       10858 non-null  int64
#  10  bronze       10858 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 1017.9+ KB

# %%
data1_tratada['nationality'].unique().shape
# Out:
# (200,)

# %% [markdown]
# ##Segundo dataset

# %% [markdown]
# ##Dados dos paises em 2016

# %% [markdown]
# Dados pego no kaggle<br>
# link:

# %% [markdown]
# https://www.kaggle.com/datasets/rio2016/olympic-games?select=countries.csv

# %% [markdown]
# Criando o dataframe com os arquivos

# %%
data2 = pd.read_csv("countries.csv")

# %% [markdown]
# exibindo as 5 primeiras linhas para analisar

# %%
data2.head() # Comando para mostrar as primeiras 5 linhas do dataframe
# Out:
#            country code  population  gdp_per_capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %% [markdown]
# olhando as 5 ultimas linhas

# %%
data2.tail()
# Out:
#              country code  population  gdp_per_capita
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819

# %% [markdown]
# Vendo informacoes sobre o dataframe e vendo os dados ausentes

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         201 non-null    object
#  1   code            201 non-null    object
#  2   population      196 non-null    float64
#  3   gdp_per_capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# E possivel ver que existem 5 valores ausentes em population e 25 valores ausentes em gdp_per_capita que precisarao ser tratados

# %% [markdown]
# Vendo informacoes descritivas

# %%
data2.describe()
# Out:
#          population  gdp_per_capita
# count  1.960000e+02      176.000000
# mean   3.722825e+07    12882.556131
# std    1.399655e+08    17747.141203
# min    1.022200e+04      277.068309
# 25%    1.638278e+06     1781.096847
# 50%    7.450124e+06     5233.583395
# 75%    2.557454e+07    15494.683646
# max    1.371220e+09   101449.968168

# %% [markdown]
# Vendo se existem valores duplicados

# %%
data2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# existem 0 valores duplicados na tabela

# %% [markdown]
# ##Tratamento de dados ausentes

# %% [markdown]
# Vendo quais sao os valores ausentes de population

# %%
data2[data2['population'].isna()]
# Out:
#                              country code  population  gdp_per_capita
# 45                      Cook Islands  COK         NaN             NaN
# 61                           Eritrea  ERI         NaN             NaN
# 130            Netherlands Antilles*  AHO         NaN             NaN
# 139  Palestine, Occupied Territories  PLE         NaN             NaN
# 177                           Taiwan  TPE         NaN             NaN

# %% [markdown]
# Devido ao numero ser pequeno, o grupo optou por pesquisar um a um na internet e ir preenchendo seus valores

# %% [markdown]
# Preenchendo Cook Islands

# %%
data2.iat[45,2]=17459

# %% [markdown]
# Preenchendo Eritrea

# %%
data2.iat[61,2]=5068831

# %% [markdown]
# Preenchendo Netherlands Antilles

# %%
data2.iat[130,2]=25020

# %% [markdown]
# Preenchendo Palestine, Occupied Territories

# %%
data2.iat[139,2]=4880000

# %% [markdown]
# Preenchendo Taiwan

# %%
data2.iat[177,2]=23540000

# %%
data2[data2['population'].isna()]
# Out:
# Empty DataFrame
# Columns: [country, code, population, gdp_per_capita]
# Index: []

# %% [markdown]
# Population nao possui mais valores nulos

# %% [markdown]
# **Vendo quais sao os valores ausentes do PIB**

# %%
data2[data2['gdp_per_capita'].isna()]
# Out:
#                              country code  population  gdp_per_capita
# 3                    American Samoa*  ASA     55538.0             NaN
# 4                            Andorra  AND     70473.0             NaN
# 9                             Aruba*  ARU    103889.0             NaN
# 20                          Bermuda*  BER     65235.0             NaN
# 27            British Virgin Islands  IVB     30117.0             NaN
# 36                   Cayman Islands*  CAY     59967.0             NaN
# 45                      Cook Islands  COK     17459.0             NaN
# 49                              Cuba  CUB  11389562.0             NaN
# 61                           Eritrea  ERI   5068831.0             NaN
# 74                              Guam  GUM    169885.0             NaN
# 86                              Iran  IRI  79109272.0             NaN
# 96                      Korea, North  PRK  25155317.0             NaN
# ...

# %% [markdown]
# Devido ao numero de valores ausentes ser alto, e muitos dos paises serem paises de dificil acesso a informacoes, sendo assim nao tendo informacoes ou com informacoes presentes na internet sem ter 100% de certeza quanto a sua veracidade, alem de nao serem paises com muito impacto e relevancia nas olimpiadas, foi optado por calcular uma media da coluna e preencher seus valores com ela.

# %% [markdown]
# Pegando a media e colocando ela em linhas que possem os valores nulos naquela coluna

# %%
median = data2["gdp_per_capita"].median()
data2["gdp_per_capita"].fillna(median, inplace=True)

# %% [markdown]
# verificando que a coluna nao possui mais valores nulos

# %%
data2[data2['gdp_per_capita'].isna()]
# Out:
# Empty DataFrame
# Columns: [country, code, population, gdp_per_capita]
# Index: []

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         201 non-null    object
#  1   code            201 non-null    object
#  2   population      201 non-null    float64
#  3   gdp_per_capita  201 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# ##Terceiro dataset

# %% [markdown]
# dados pegos no kaggle<br>
# link:

# %% [markdown]
# https://www.kaggle.com/datasets/phoebec216/summer-olympics-medal-tables-1896-2012

# %% [markdown]
# Criando o dataframe com os arquivos

# %%
data3 = pd.read_csv("SummerOlympics_medals.csv")

# %% [markdown]
# exibindo as 5 primeiras linhas para analisar

# %%
data3.head()
# Out:
#    Rank  Year                               Country  Golds  Silvers  Bronzes  \
# 0     1  1984                         United States     82       61       30
# 1     1  1980  Former Soviet Union / Russian Empire     80       69       46
# 2     1  1904                         United States     77       82       74
# 3     1  1908                        United Kingdom     56       50       37
# 4     1  1988  Former Soviet Union / Russian Empire     54       31       46
#
#    Medals
# 0     173
# 1     195
# 2     233
# 3     143
# 4     131

# %% [markdown]
# exibindo as 5 ultimas linhas

# %%
data3.tail()
# Out:
#       Rank  Year    Country  Golds  Silvers  Bronzes  Medals
# 1152    81  2008     Israel      0        0        1       1
# 1153    81  2008  Mauritius      0        0        1       1
# 1154    81  2008    Moldova      0        0        1       1
# 1155    81  2008       Togo      0        0        1       1
# 1156    81  2008  Venezuela      0        0        1       1

# %% [markdown]
# A coluna rank nao vai ter utilidade e por isso vai ser eliminada

# %%
data3=data3.drop('Rank',axis=1)

# %% [markdown]
# Separando so nos anos desejados

# %%
data3_2012=data3[data3['Year']==2012]

# %%
data3_2012.reset_index(inplace=True, drop=True)

# %% [markdown]
# Vendo as informacoes dos dataframes e se possuem dados ausentes

# %%
data3_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     85 non-null     int64
#  1   Country  85 non-null     object
#  2   Golds    85 non-null     int64
#  3   Silvers  85 non-null     int64
#  4   Bronzes  85 non-null     int64
#  5   Medals   85 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 4.1+ KB

# %% [markdown]
# O dataset nao possui nenhum valor ausente

# %% [markdown]
# Fazendo describe para obter informacoes destritivas

# %%
data3_2012.describe()
# Out:
#          Year      Golds    Silvers    Bronzes      Medals
# count    85.0  85.000000  85.000000  85.000000   85.000000
# mean   2012.0   3.564706   3.588235   4.152941   11.305882
# std       0.0   7.574153   5.934753   5.840144   18.640090
# min    2012.0   0.000000   0.000000   0.000000    1.000000
# 25%    2012.0   0.000000   1.000000   1.000000    2.000000
# 50%    2012.0   1.000000   1.000000   2.000000    4.000000
# 75%    2012.0   3.000000   4.000000   5.000000   11.000000
# max    2012.0  47.000000  31.000000  30.000000  104.000000

# %% [markdown]
# Exibindo as 5 primeiras linhas

# %%
data3_2012.head()
# Out:
#    Year             Country  Golds  Silvers  Bronzes  Medals
# 0  2012       United States     47       27       30     104
# 1  2012               China     38       31       22      91
# 2  2012      United Kingdom     29       18       18      65
# 3  2012  Russian Federation     20       21       28      69
# 4  2012         South Korea     13        9        8      30

# %% [markdown]
# Vendo se existem linhas repetidas

# %%
data3_2012.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Nenhum valor duplicado foi identificado

# %% [markdown]
# ##Alterando e juntando os datset

# %% [markdown]
# Observando suas estruturas:

# %%
data1_tratada.head(1)
# Out:
#           id            name nationality   sex       dob  height  weight  \
# 0  736041664  A Jesus Garcia         ESP  male  10/17/69    1.72    64.0
#
#        sport  gold  silver  bronze
# 0  athletics     0       0       0

# %%
data2.head(1)
# Out:
#        country code  population  gdp_per_capita
# 0  Afghanistan  AFG  32526562.0      594.323081

# %% [markdown]
# Devido a coluna 'id' do primeiro dataset nao ter nenhuma utilidade ela vai ser eliminada

# %%
data1_tratada=data1_tratada.drop('id',axis=1)

# %% [markdown]
# Devido a coluna 'dob' do primeiro dataset nao ter nenhuma utilidade ela vai ser eliminada

# %%
data1_tratada=data1_tratada.drop('dob',axis=1)

# %% [markdown]
# A sigla do pais vai ser usada para juncao dos datasets, para isso seu nome vai ter que ser mudada no segundo dataset

# %%
data2.rename(columns = {'code':'nationality'}, inplace = True)

# %% [markdown]
# ##Juntando os dois dataset

# %%
data_final = pd.merge(data1_tratada, data2, on="nationality")

# %% [markdown]
# Exibindo as 5 primeiras linhas para ver como ficou

# %%
data_final.head()
# Out:
#                     name nationality     sex  height  weight       sport  \
# 0         A Jesus Garcia         ESP    male    1.72    64.0   athletics
# 1    Aauri Lorena Bokesa         ESP  female    1.80    62.0   athletics
# 2    Abdelaziz Merzougui         ESP    male    1.75    67.0   athletics
# 3           Adel Mechaal         ESP    male    1.82    71.0   athletics
# 4  Adrian Gavira Collado         ESP    male    1.93    89.0  volleyball
#
#    gold  silver  bronze country  population  gdp_per_capita
# 0     0       0       0   Spain  46418269.0    25831.582305
# 1     0       0       0   Spain  46418269.0    25831.582305
# 2     0       0       0   Spain  46418269.0    25831.582305
# 3     0       0       0   Spain  46418269.0    25831.582305
# 4     0       0       0   Spain  46418269.0    25831.582305

# %%
data_final[data_final['name']=='Zurian Hechavarria']
# Out:
#                     name nationality     sex  height  weight      sport  gold  \
# 5138  Zurian Hechavarria         CUB  female    1.64    58.0  athletics     0
#
#       silver  bronze country  population  gdp_per_capita
# 5138       0       0    Cuba  11389562.0     5233.583395

# %%
data_final['gdp_per_capita'].max()
# Out:
# 101449.968168042

# %%
data_final[data_final['gdp_per_capita']==101449.968168042]
# Out:
#                       name nationality     sex  height  weight         sport  \
# 10329     Chantal Hoffmann         LUX  female    1.67    62.0       cycling
# 10330      Charles Grethen         LUX    male    1.80    68.0     athletics
# 10331     Charline Mathias         LUX  female    1.73    60.0     athletics
# 10332    Christine Majerus         LUX  female    1.74    57.0       cycling
# 10333        Frank Schleck         LUX    male    1.85    63.0       cycling
# 10334        Gilles Muller         LUX    male    1.93    90.0        tennis
# 10335         Julie Meynen         LUX  female    1.70    63.0      aquatics
# 10336       Laurent Carnol         LUX    male    1.87    82.0      aquatics
# 10337  Raphael Stacchiotti         LUX    male    1.83    80.0      aquatics
# 10338          Xia Lian Ni         LUX  female    1.57    58.0  table tennis
#
#        gold  silver  bronze     country  population  gdp_per_capita
# ...

# %%
data_final[data_final['nationality']=='USA']
# Out:
#                     name nationality     sex  height  weight         sport  \
# 1473       Aaron Russell         USA    male    2.05    98.0    volleyball
# 1474    Abbey D'Agostino         USA  female    1.61    49.0     athletics
# 1475      Abbey Weitzeil         USA  female    1.78    68.0      aquatics
# 1476    Abigail Johnston         USA  female    1.66    61.0      aquatics
# 1477  Adeline Maria Gray         USA  female    1.73    77.0     wrestling
# ...                  ...         ...     ...     ...     ...           ...
# 2020          Yijun Feng         USA    male    1.86    71.0  table tennis
# 2021              Yue Wu         USA  female    1.61    50.0  table tennis
# 2022        Zach Garrett         USA    male    1.78    63.0       archery
# 2023         Zach Ziemek         USA    male    1.94    88.0     athletics
# 2024           Zack Test         USA    male    1.91    92.0  rugby sevens
#
# ...

# %%
data_final['population'].max()
# Out:
# 1371220000.0

# %%
data_final[data_final['population']==1371220000.0]
# Out:
#                name nationality     sex  height  weight       sport  gold  \
# 7022    Aichen Wang         CHN    male    1.85    75.0     sailing     0
# 7023      Ailun Guo         CHN    male    1.92    85.0  basketball     0
# 7024     Aisen Chen         CHN    male    1.68    60.0    aquatics     2
# 7025  Alex Hua Tian         CHN    male    1.90    70.0  equestrian     0
# 7026        Anqi Xu         CHN  female    1.82    76.0     fencing     0
# ...             ...         ...     ...     ...     ...         ...   ...
# 7410      Zibei Yan         CHN    male    1.90    75.0    aquatics     0
# 7411    Zicheng Hui         CHN    male    1.77    70.0    shooting     0
# 7412     Zihan Zhao         CHN  female    1.72    62.0    aquatics     0
# 7413       Zixia Ou         CHN  female    1.68    61.0      hockey     0
# 7414        di Xiao         CHN    male    1.85   100.0   wrestling     0
#
#       silver  bronze country    population  gdp_per_capita
# ...

# %% [markdown]
# Mudando o data 3 para poder juntar ele

# %% [markdown]
# Drop na coluna Yaer pois ela nao vai ser usada

# %%
data3_2012=data3_2012.drop('Year',axis=1)

# %%
data3_2012.head()
# Out:
#               Country  Golds  Silvers  Bronzes  Medals
# 0       United States     47       27       30     104
# 1               China     38       31       22      91
# 2      United Kingdom     29       18       18      65
# 3  Russian Federation     20       21       28      69
# 4         South Korea     13        9        8      30

# %% [markdown]
# Substituindo o nome das colunas para elas serem identificaveis depois da juncao dos dataset

# %%
data3_2012.rename(columns = {'Country':'country','Golds':'gold_2012','Silvers':'silver_2012','Bronzes':'bronze_2012','Medals':'total_2012'}, inplace = True)

# %%
data3_2012.head()
# Out:
#               country  gold_2012  silver_2012  bronze_2012  total_2012
# 0       United States         47           27           30         104
# 1               China         38           31           22          91
# 2      United Kingdom         29           18           18          65
# 3  Russian Federation         20           21           28          69
# 4         South Korea         13            9            8          30

# %% [markdown]
# Foi identificado que os dataset possuem os mesmos paises porem alguns desses paises estao com nomes diferentes em cada um, exibindo essa lista para ser analisado

# %%
a=data3_2012['country'].unique()

# %%
a
# Out:
# array(['United States', 'China', 'United Kingdom', 'Russian Federation',
#        'South Korea', 'Germany', 'France', 'Australia', 'Italy',
#        'Hungary', 'Japan', 'Netherlands', 'Iran', 'Ukraine',
#        'New Zealand', 'Cuba', 'Spain', 'Jamaica', 'Czech Republic',
#        'South Africa', 'North Korea', 'Brazil', 'Ethiopia', 'Kazakhstan',
#        'Poland', 'Croatia', 'Canada', 'Belarus', 'Romania', 'Kenya',
#        'Denmark', 'Azerbaijan', 'Switzerland', 'Lithuania', 'Norway',
#        'Tunisia', 'Sweden', 'Colombia', 'Mexico', 'Georgia', 'Ireland',
#        'Argentina', 'Serbia', 'Slovenia', 'Trinidad and Tobago', 'Turkey',
#        'Dominican Republic', 'Latvia', 'Taiwan (ROC)', 'Algeria',
#        'Bahamas', 'Bahrain', 'Grenada', 'Uganda', 'Venezuela', 'Egypt',
#        'India', 'Mongolia', 'Thailand', 'Bulgaria', 'Finland',
#        'Indonesia', 'Slovakia', 'Belgium', 'Armenia', 'Estonia',
#        'Malaysia', 'Puerto Rico', 'Qatar', 'Botswana', 'Cyprus', 'Gabon',
# ...

# %%
b=data_final['country'].unique()

# %%
b
# Out:
# array(['Spain', 'Korea, South', 'Canada', 'Moldova', 'New Zealand',
#        'Australia', 'United States', 'Ethiopia', 'Bahrain',
#        'United Kingdom', 'Uzbekistan', 'South Africa', 'Egypt', 'Morocco',
#        'Qatar', 'Sudan', 'Algeria', 'Denmark', 'Netherlands', 'Djibouti',
#        'Senegal', 'Cameroon', 'Niger', 'Sweden', 'Afghanistan',
#        'Saudi Arabia', 'Russia', 'India', 'Hungary', 'Burundi', 'Eritrea',
#        'Poland', 'Brazil', 'Georgia', 'Czech Republic', 'Seychelles',
#        'Lithuania', 'Iran', 'Cuba', 'Slovenia', 'Bahamas', 'Italy',
#        'Argentina', 'Puerto Rico*', 'France', 'Rwanda', 'Togo', 'Tunisia',
#        'Israel', 'Nigeria', 'Latvia', 'Jordan', 'Malaysia', 'Lebanon',
#        'Iraq', 'Turkey', 'Venezuela', 'Japan', 'Taiwan', 'Kyrgyzstan',
#        'China', 'Mexico', 'Greece', 'Ireland', 'Kazakhstan', 'Jamaica',
#        'Switzerland', 'Barbados', 'Honduras', 'Angola', 'Germany',
# ...

# %% [markdown]
# Foi identificado que existem paises que sao os mesmo, porem estao com nomes diferentes

# %% [markdown]
# Mudando o nome de paises que sao os memos mas estao com nomes diferentes nos dataset

# %%
data3_2012=data3_2012.replace(['South Korea'], 'Korea, South')

# %%
data3_2012=data3_2012.replace(['North Korea'], 'Korea, North')

# %%
data3_2012=data3_2012.replace(['Russian Federation'], 'Russia')

# %%
data3_2012=data3_2012.replace(['Puerto Rico'], 'Puerto Rico*')

# %%
data3_2012=data3_2012.replace(['Taiwan (ROC)'], 'Taiwan')

# %%
data3_2012=data3_2012.replace(['Hong Kong'], 'Hong Kong*')

# %% [markdown]
# Foi identifcado a existencia de paises presente no 1 dataset que tinham medalhas, porem nao estavam no terceiro, por isso eles vao ser adicionados

# %%
data3_2012 = data3_2012.append({'country': 'Nigeria','gold_2012':0, 'silver_2012':0,'bronze_2012':1,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Burundi','gold_2012':0, 'silver_2012':1,'bronze_2012':0,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Israel','gold_2012':0, 'silver_2012':0,'bronze_2012':2,'total_2012':2}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Jordan','gold_2012':1, 'silver_2012':0,'bronze_2012':0,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Kyrgyzstan','gold_2012':0, 'silver_2012':0,'bronze_2012':1,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Austria','gold_2012':0, 'silver_2012':0,'bronze_2012':1,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'United Arab Emirates','gold_2012':0, 'silver_2012':0,'bronze_2012':1,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Fiji','gold_2012':1, 'silver_2012':0,'bronze_2012':0,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Vietnam','gold_2012':1, 'silver_2012':1,'bronze_2012':0,'total_2012':2}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': 'Philippines','gold_2012':0, 'silver_2012':1,'bronze_2012':0,'total_2012':1}, ignore_index=True)

# %%
data3_2012 = data3_2012.append({'country': '''Cote d'Ivoire''','gold_2012':1, 'silver_2012':0,'bronze_2012':1,'total_2012':2}, ignore_index=True)

# %%
data3_2012.tail()
# Out:
#                  country  gold_2012  silver_2012  bronze_2012  total_2012
# 91  United Arab Emirates          0            0            1           1
# 92                  Fiji          1            0            0           1
# 93               Vietnam          1            1            0           2
# 94           Philippines          0            1            0           1
# 95         Cote d'Ivoire          1            0            1           2

# %% [markdown]
# Juntando os dataset

# %%
data_final = pd.merge(data_final, data3_2012, on="country")

# %% [markdown]
# Exibindo as 5 primeiras linhas para ver como ficou

# %%
data_final.head()
# Out:
#                     name nationality     sex  height  weight       sport  \
# 0         A Jesus Garcia         ESP    male    1.72    64.0   athletics
# 1    Aauri Lorena Bokesa         ESP  female    1.80    62.0   athletics
# 2    Abdelaziz Merzougui         ESP    male    1.75    67.0   athletics
# 3           Adel Mechaal         ESP    male    1.82    71.0   athletics
# 4  Adrian Gavira Collado         ESP    male    1.93    89.0  volleyball
#
#    gold  silver  bronze country  population  gdp_per_capita  gold_2012  \
# 0     0       0       0   Spain  46418269.0    25831.582305          4
# 1     0       0       0   Spain  46418269.0    25831.582305          4
# 2     0       0       0   Spain  46418269.0    25831.582305          4
# 3     0       0       0   Spain  46418269.0    25831.582305          4
# 4     0       0       0   Spain  46418269.0    25831.582305          4
#
#    silver_2012  bronze_2012  total_2012
# 0           10            5          19
# ...

# %% [markdown]
# A coluna nationality e country estao passando a mesma informacao, por isso a nationality vai ser eliminada

# %%
data_final=data_final.drop('nationality',axis=1)

# %%
data_final.head()
# Out:
#                     name     sex  height  weight       sport  gold  silver  \
# 0         A Jesus Garcia    male    1.72    64.0   athletics     0       0
# 1    Aauri Lorena Bokesa  female    1.80    62.0   athletics     0       0
# 2    Abdelaziz Merzougui    male    1.75    67.0   athletics     0       0
# 3           Adel Mechaal    male    1.82    71.0   athletics     0       0
# 4  Adrian Gavira Collado    male    1.93    89.0  volleyball     0       0
#
#    bronze country  population  gdp_per_capita  gold_2012  silver_2012  \
# 0       0   Spain  46418269.0    25831.582305          4           10
# 1       0   Spain  46418269.0    25831.582305          4           10
# 2       0   Spain  46418269.0    25831.582305          4           10
# 3       0   Spain  46418269.0    25831.582305          4           10
# 4       0   Spain  46418269.0    25831.582305          4           10
#
#    bronze_2012  total_2012
# 0            5          19
# 1            5          19
# ...

# %%
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9829 entries, 0 to 9828
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            9829 non-null   object
#  1   sex             9829 non-null   object
#  2   height          9829 non-null   float64
#  3   weight          9829 non-null   float64
#  4   sport           9829 non-null   object
#  5   gold            9829 non-null   int64
#  6   silver          9829 non-null   int64
#  7   bronze          9829 non-null   int64
#  8   country         9829 non-null   object
#  9   population      9829 non-null   float64
#  10  gdp_per_capita  9829 non-null   float64
#  11  gold_2012       9829 non-null   int64
#  12  silver_2012     9829 non-null   int64
#  13  bronze_2012     9829 non-null   int64
#  14  total_2012      9829 non-null   int64
# dtypes: float64(4), int64(7), object(4)
# memory usage: 1.2+ MB

# %%
data_final.describe()
# Out:
#             height       weight         gold       silver       bronze  \
# count  9829.000000  9829.000000  9829.000000  9829.000000  9829.000000
# mean      1.768644    72.126971     0.063994     0.061654     0.061960
# std       0.112766    16.046881     0.270054     0.248855     0.245693
# min       1.210000    31.000000     0.000000     0.000000     0.000000
# 25%       1.690000    60.000000     0.000000     0.000000     0.000000
# 50%       1.760000    70.000000     0.000000     0.000000     0.000000
# 75%       1.850000    81.000000     0.000000     0.000000     0.000000
# max       2.210000   170.000000     5.000000     2.000000     2.000000
#
#          population  gdp_per_capita    gold_2012  silver_2012  bronze_2012  \
# count  9.829000e+03     9829.000000  9829.000000  9829.000000  9829.000000
# mean   1.359332e+08    25952.367462     9.246515     8.689083     9.260657
# std    2.949293e+08    19548.527483    12.802799     8.925469     8.322558
# ...

# %%
data_final.to_csv('Dados_A3_Analise.csv', index=False)
